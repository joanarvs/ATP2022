# %% [markdown]
# ### TPC3: Aplicação para manipulação de listas de inteiros
# - Crie uma aplicação em Python que coloca no monitor o seguinte menu:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# - O utilizador irá escolher uma das opções introduzindo o número correspondente;
# - Se a opção não for sair, a aplicação executa a operação pretendida, apresenta o resultado e a seguir apresenta de novo o menu;
# - Se a opção for sair, a aplicação termina colocando uma mensagem no monitor.
#
# * No desenvolvimento da aplicação deverá ter em atenção o seguinte:
#     - A aplicação terá uma variável interna para guardar uma lista de números;
#     - Na opção 1, deverá ser criada uma lista de números aleatórios entre 1 e 100 que será guardada na variável interna;
#     - Na opção 2, deverá ser criada uma lista com números introduzidos pelo utilizador, que será guardada na variável interna;
#     - Nestas primeiras opções, se a variável interna já tiver uma lista, esta será sobreposta/apagada pela nova lista;
#     - Na opção 3, será calculada a soma dos elementos na lista no momento;
#     - Na opção 4, será calculada a média dos elementos na lista no momento;
#     - Na opção 5, será calculado o maior elemento da lista no momento;
#     - Na opção 6, será calculado o menor elemento da lista no momento;
#     - Na opção 7, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem crescente;
#     - Na opção 8, a aplicação deverá indicar (Sim/Não) se a lista está ordenada por ordem decrescente;
#     - Na opção 9, a aplicação irá procurar um ellmento na lista, se o encontrar deverá devolver a sua posição;
#     - Se o utilizador selecionar a opção 0, a aplicação deverá terminar mostrando a lista que está nesse momento guardada.

# %%
import random

def criarLista1(nelems):
    l1 = []
    while len(l1) < nelems:
        elem = random.randint(1, 101)
        l1.append(elem)
    return (l1)

def criarLista2(nelems):
    l2 = []
    i = 1
    while len(l2) < nelems:
        elem = int(input("Introduza o elemento " + str(i) + ": "))
        l2.append(elem)
        i = i + 1
    return l2

def somaLista(varint):
    soma = 0
    for i in varint:
        soma = soma + i
    return soma

def mediaLista(lista):
    total = len(lista)
    soma = 0
    for i in lista:
        soma = soma + i
    return soma/total

def maiorLista(lista):
    maior = lista[0]
    for i in lista:
        if i > maior:
            maior = i
    return maior

def menorLista(lista):
    menor = lista[0]
    for i in lista:
        if i < menor:
            menor = i
    return menor

def estaOrdenada(lista):
    anterior = lista[0]
    i = 1
    while i < len(lista):
        if lista[i] > anterior:
            anterior= lista[i]
            i = i + 1
        else:
            print ("Não")
            return 
    print("Sim")

def estaOrdenadaD(lista):
    anterior = lista[0]
    i = 1
    while i < len(lista):
        if lista[i] < anterior:
            anterior= lista[i]
            i = i + 1
        else:
            print ("Não")
            return
    print("Sim")

def procuraelem(lista, ellmento):
    ind = 0
    for i in lista:
        if i == ellmento:
            print ("Está na posição:",ind)
            return
        ind = ind + 1
    print ("Não está")

def tpc3():
    menu = """(1) Criar Lista | (2) Ler Lista | (3) Soma | (4) Média | (5) Maior | (6) Menor |(7) Está ordenada por ordem crescente | 
(8) Está ordenada por ordem decrescente | (9) Procura um elemento | (0) Sair"""
    print(menu) 
    option = int(input("Selecione uma opção"))
    varint = []
    while option in range(1,10):
        if option == 1:
            nelems = int(input("Lista com quantos elementos?"))
            varint = criarLista1(nelems)
            print(varint)
        if option == 2:
            nelems = int(input("Lista com quantos elementos?"))
            varint = criarLista2(nelems)
            print(varint)
        if option == 3:
            print("Soma dos elementos da lista: ", somaLista(varint))
        if option == 4:
            print("Média da lista:", mediaLista(varint))
        if option == 5:
            print("Maior da lista:", maiorLista(varint))
        if option == 6:
            print("Menor da lista:", menorLista(varint))
        if option == 7:
            estaOrdenada(varint)
        if option == 8:
            estaOrdenadaD(varint)
        if option == 9:
            ellmento = int(input("Procure um elemento da lista"))
            procuraelem(varint, ellmento)
        print(menu)
        option = int(input("Selecione uma opção"))
    if option == 0:
        print("""Terminou
Lista:""", varint)

    
tpc3()
# Out:
# (1) Criar Lista | (2) Ler Lista | (3) Soma | (4) Média | (5) Maior | (6) Menor |(7) Está ordenada por ordem crescente |
# (8) Está ordenada por ordem decrescente | (9) Procura um elemento | (0) Sair
# Terminou
# Lista: []
